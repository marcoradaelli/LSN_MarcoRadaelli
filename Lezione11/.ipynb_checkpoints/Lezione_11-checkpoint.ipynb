# %% [markdown]
# # Regressione lineare #
# In quanto segue tento di addestrare una rete neurale per la regressione lineare. Dapprima eseguo tutto usando un solo neurone, la cui capacità rappresentativa a due parametri addestrabili (non usando la funzione di attivazione che introduce un effetto di non linearità) basta per rappresentare la complessità del problema.

# %% [markdown]
# Considero la retta da fittare:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Definisco i parametri della retta.

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Genero ora dati "sporcati" rispetto a dei perfetti dati sulla retta tramite del rumore gaussiano.

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 10)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function
# Non useremo i dati y_target.

sigma = 0.01 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %% [markdown]
# Creo un modello di rete neurale usando con un solo neurone.

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()  # Modello sequenziale
model.add(Dense(1, input_shape=(1,)))  # Aggiungo un layer fatto da un solo neurone.

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Eseguo ora il training della rete neurale.

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=16, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Train on 1000 samples, validate on 10 samples
# Epoch 1/30
# 1000/1000 [==============================] - 0s 117us/sample - loss: 9.3671e-05 - mean_squared_error: 9.3671e-05 - val_loss: 7.0922e-05 - val_mean_squared_error: 7.0922e-05
# Epoch 2/30
# 1000/1000 [==============================] - 0s 127us/sample - loss: 9.3650e-05 - mean_squared_error: 9.3650e-05 - val_loss: 7.1114e-05 - val_mean_squared_error: 7.1114e-05
# Epoch 3/30
# 1000/1000 [==============================] - 0s 141us/sample - loss: 9.3635e-05 - mean_squared_error: 9.3635e-05 - val_loss: 7.0420e-05 - val_mean_squared_error: 7.0420e-05
# Epoch 4/30
# 1000/1000 [==============================] - 0s 120us/sample - loss: 9.3654e-05 - mean_squared_error: 9.3654e-05 - val_loss: 6.9966e-05 - val_mean_squared_error: 6.9966e-05
# Epoch 5/30
# 1000/1000 [==============================] - 0s 118us/sample - loss: 9.3650e-05 - mean_squared_error: 9.3650e-05 - val_loss: 6.9046e-05 - val_mean_squared_error: 6.9046e-05
# Epoch 6/30
# 1000/1000 [==============================] - 0s 121us/sample - loss: 9.3660e-05 - mean_squared_error: 9.3660e-05 - val_loss: 6.9054e-05 - val_mean_squared_error: 6.9054e-05
# Epoch 7/30
# 1000/1000 [==============================] - 0s 132us/sample - loss: 9.3698e-05 - mean_squared_error: 9.3698e-05 - val_loss: 6.9665e-05 - val_mean_squared_error: 6.9665e-05
# Epoch 8/30
# 1000/1000 [==============================] - 0s 136us/sample - loss: 9.3661e-05 - mean_squared_error: 9.3661e-05 - val_loss: 7.0042e-05 - val_mean_squared_error: 7.0042e-05
# Epoch 9/30
# 1000/1000 [==============================] - 0s 134us/sample - loss: 9.3636e-05 - mean_squared_error: 9.3636e-05 - val_loss: 7.0019e-05 - val_mean_squared_error: 7.0019e-05
# Epoch 10/30
# 1000/1000 [==============================] - 0s 129us/sample - loss: 9.3652e-05 - mean_squared_error: 9.3652e-05 - val_loss: 6.9555e-05 - val_mean_squared_error: 6.9555e-05
# Epoch 11/30
# 1000/1000 [==============================] - ETA: 0s - loss: 9.4959e-05 - mean_squared_error: 9.4959e- - 0s 119us/sample - loss: 9.3663e-05 - mean_squared_error: 9.3663e-05 - val_loss: 6.9425e-05 - val_mean_squared_error: 6.9425e-05
# Epoch 12/30
# 1000/1000 [==============================] - 0s 131us/sample - loss: 9.3658e-05 - mean_squared_error: 9.3658e-05 - val_loss: 7.0228e-05 - val_mean_squared_error: 7.0228e-05
# Epoch 13/30
# 1000/1000 [==============================] - 0s 125us/sample - loss: 9.3632e-05 - mean_squared_error: 9.3632e-05 - val_loss: 7.0707e-05 - val_mean_squared_error: 7.0707e-05
# Epoch 14/30
# 1000/1000 [==============================] - 0s 111us/sample - loss: 9.3666e-05 - mean_squared_error: 9.3666e-05 - val_loss: 7.1038e-05 - val_mean_squared_error: 7.1038e-05
# Epoch 15/30
# 1000/1000 [==============================] - 0s 119us/sample - loss: 9.3696e-05 - mean_squared_error: 9.3696e-05 - val_loss: 6.9431e-05 - val_mean_squared_error: 6.9431e-05
# Epoch 16/30
# 1000/1000 [==============================] - 0s 118us/sample - loss: 9.3646e-05 - mean_squared_error: 9.3646e-05 - val_loss: 6.9507e-05 - val_mean_squared_error: 6.9507e-05
# Epoch 17/30
# 1000/1000 [==============================] - 0s 129us/sample - loss: 9.3666e-05 - mean_squared_error: 9.3666e-05 - val_loss: 6.9852e-05 - val_mean_squared_error: 6.9852e-05
# Epoch 18/30
# 1000/1000 [==============================] - 0s 127us/sample - loss: 9.3628e-05 - mean_squared_error: 9.3628e-05 - val_loss: 7.1477e-05 - val_mean_squared_error: 7.1477e-05
# Epoch 19/30
# 1000/1000 [==============================] - 0s 132us/sample - loss: 9.3661e-05 - mean_squared_error: 9.3661e-05 - val_loss: 7.0304e-05 - val_mean_squared_error: 7.0304e-05
# Epoch 20/30
# 1000/1000 [==============================] - 0s 115us/sample - loss: 9.3626e-05 - mean_squared_error: 9.3626e-05 - val_loss: 7.0184e-05 - val_mean_squared_error: 7.0184e-05
# Epoch 21/30
# 1000/1000 [==============================] - 0s 121us/sample - loss: 9.3656e-05 - mean_squared_error: 9.3656e-05 - val_loss: 7.0419e-05 - val_mean_squared_error: 7.0419e-05
# Epoch 22/30
# 1000/1000 [==============================] - 0s 114us/sample - loss: 9.3645e-05 - mean_squared_error: 9.3645e-05 - val_loss: 6.9933e-05 - val_mean_squared_error: 6.9933e-05
# Epoch 23/30
# 1000/1000 [==============================] - 0s 105us/sample - loss: 9.3634e-05 - mean_squared_error: 9.3634e-05 - val_loss: 7.0077e-05 - val_mean_squared_error: 7.0077e-05
# Epoch 24/30
# 1000/1000 [==============================] - 0s 135us/sample - loss: 9.3646e-05 - mean_squared_error: 9.3646e-05 - val_loss: 7.1009e-05 - val_mean_squared_error: 7.1009e-05
# Epoch 25/30
# 1000/1000 [==============================] - 0s 109us/sample - loss: 9.3617e-05 - mean_squared_error: 9.3617e-05 - val_loss: 6.9660e-05 - val_mean_squared_error: 6.9660e-05
# Epoch 26/30
# 1000/1000 [==============================] - 0s 117us/sample - loss: 9.3626e-05 - mean_squared_error: 9.3626e-05 - val_loss: 7.1163e-05 - val_mean_squared_error: 7.1163e-05
# Epoch 27/30
# 1000/1000 [==============================] - 0s 123us/sample - loss: 9.3649e-05 - mean_squared_error: 9.3649e-05 - val_loss: 7.1534e-05 - val_mean_squared_error: 7.1534e-05
# Epoch 28/30
# 1000/1000 [==============================] - 0s 131us/sample - loss: 9.3617e-05 - mean_squared_error: 9.3617e-05 - val_loss: 7.0134e-05 - val_mean_squared_error: 7.0134e-05
# Epoch 29/30
# 1000/1000 [==============================] - 0s 126us/sample - loss: 9.3609e-05 - mean_squared_error: 9.3609e-05 - val_loss: 6.9704e-05 - val_mean_squared_error: 6.9704e-05
# Epoch 30/30
# 1000/1000 [==============================] - 0s 126us/sample - loss: 9.3637e-05 - mean_squared_error: 9.3637e-05 - val_loss: 7.0516e-05 - val_mean_squared_error: 7.0516e-05

# %%
# return weights
model.get_weights()
# Out:
# [array([[1.9994748]], dtype=float32), array([1.000269], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10/10 [==============================] - 0s 96us/sample - loss: 7.0516e-05 - mean_squared_error: 7.0516e-05
#
# Test loss: 7.051642751321197e-05
# Test accuracy: 7.051643e-05

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 10/10 [==============================] - 0s 149us/sample - loss: 2.3066e-07 - mean_squared_error: 2.3066e-07
#
# Test loss: 2.3066195353749208e-07
# Test accuracy: 2.3066195e-07

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# # Fit polinomiale #
# Ora il mio obiettivo è quello di creare un fit polinomiale di dati noisy a partire da un polinomio di terzo grado:
# $$
# f(x) = 4 - 3x - 2x^2 +3x^3
# $$

# %%
# Imposto i parametri del polinomio.
a = 4
b = -3
c = -2
d = 3

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 5000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = a + b * x_valid + c * x_valid**2 + d * x_valid**3 # ideal (target) linear function
# Non useremo i dati y_target.

sigma = 0.01 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(a + b * x_train + c * x_train**2 + d * x_train**3, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(a + b * x_valid + c * x_valid**2 + d * x_valid**3, sigma)

# Qui faccio stampare i dati che ho.
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %% [markdown]
# Dopo alcuni tentativi, ho deciso di realizzare una rete neurale fatta in questo modo:
# <ul>
#     <li>Un layer di input a singolo neurone, privo di funzione di attivazione </li>
#     <li>Un layer profondo da 20 neuroni con attivazione a tangente iperbolica</li>
#     <li>Un layer profondo da 20 neuroni con attivazione RELU</li>
#     <li>Un layer profondo da 10 neuroni con attivazione a tangente iperbolica</li>
#     <li>Un layer di output a singolo neurone, privo di funzione di attivazione.
# </ul>

# %%
# In questo blocco preparo la rete neurale.
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()  # Modello sequenziale
model.add(Dense(1, input_shape=(1,)))  # Aggiungo un layer fatto da un solo neurone.
model.add(Dense(20,activation = 'tanh'))   # Qui ho un altro layer di 10 neuroni con una RELU come
# funzione di attivazione.
model.add(Dense(20,activation = 'relu'))
model.add(Dense(10,activation = 'tanh'))
model.add(Dense(1,)) # Il layer di uscita ha un solo neurone, per ora senza funzione di attivazione.

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_106 (Dense)            (None, 1)                 2
# _________________________________________________________________
# dense_107 (Dense)            (None, 20)                40
# _________________________________________________________________
# dense_108 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_109 (Dense)            (None, 10)                210
# _________________________________________________________________
# dense_110 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 683
# Trainable params: 683
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Questo sistema ha quindi 683 parametri liberi. Procedo all'allenamento del sistema usando 30 epoche e una size del batch di 32.

# %%
bsize =32  # il codice funziona meglio usando potenze di 2.
# fit the model using training dataset
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=bsize, epochs=30, 
          validation_data=(x_valid, y_valid))
# Out:
# Train on 5000 samples, validate on 100 samples
# Epoch 1/30
# 5000/5000 [==============================] - 2s 475us/sample - loss: 1.0909 - mean_squared_error: 1.0909 - val_loss: 0.2789 - val_mean_squared_error: 0.2789
# Epoch 2/30
# 5000/5000 [==============================] - 1s 282us/sample - loss: 0.3583 - mean_squared_error: 0.3583 - val_loss: 0.2371 - val_mean_squared_error: 0.2371
# Epoch 3/30
# 5000/5000 [==============================] - 1s 285us/sample - loss: 0.3031 - mean_squared_error: 0.3031 - val_loss: 0.1929 - val_mean_squared_error: 0.1929
# Epoch 4/30
# 5000/5000 [==============================] - 1s 281us/sample - loss: 0.2567 - mean_squared_error: 0.2567 - val_loss: 0.1643 - val_mean_squared_error: 0.1643
# Epoch 5/30
# 5000/5000 [==============================] - 2s 380us/sample - loss: 0.2190 - mean_squared_error: 0.2190 - val_loss: 0.1370 - val_mean_squared_error: 0.1370
# Epoch 6/30
# 5000/5000 [==============================] - 2s 326us/sample - loss: 0.1777 - mean_squared_error: 0.1777 - val_loss: 0.1014 - val_mean_squared_error: 0.1014
# Epoch 7/30
# 5000/5000 [==============================] - 1s 284us/sample - loss: 0.1292 - mean_squared_error: 0.1292 - val_loss: 0.0735 - val_mean_squared_error: 0.0735
# Epoch 8/30
# 5000/5000 [==============================] - 2s 357us/sample - loss: 0.0822 - mean_squared_error: 0.0822 - val_loss: 0.0389 - val_mean_squared_error: 0.0389
# Epoch 9/30
# 5000/5000 [==============================] - 2s 323us/sample - loss: 0.0480 - mean_squared_error: 0.0480 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 10/30
# 5000/5000 [==============================] - 2s 318us/sample - loss: 0.0296 - mean_squared_error: 0.0296 - val_loss: 0.0205 - val_mean_squared_error: 0.0205
# Epoch 11/30
# 5000/5000 [==============================] - 2s 305us/sample - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0167 - val_mean_squared_error: 0.0167
# Epoch 12/30
# 5000/5000 [==============================] - 1s 255us/sample - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
# Epoch 13/30
# 5000/5000 [==============================] - 1s 295us/sample - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0125 - val_mean_squared_error: 0.0125
# Epoch 14/30
# 5000/5000 [==============================] - 2s 355us/sample - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
# Epoch 15/30
# 5000/5000 [==============================] - 1s 275us/sample - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 16/30
# 5000/5000 [==============================] - 2s 318us/sample - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
# Epoch 17/30
# 5000/5000 [==============================] - 2s 313us/sample - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0053 - val_mean_squared_error: 0.0053
# Epoch 18/30
# 5000/5000 [==============================] - 2s 344us/sample - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 19/30
# 5000/5000 [==============================] - 1s 257us/sample - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 20/30
# 5000/5000 [==============================] - 2s 331us/sample - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 21/30
# 5000/5000 [==============================] - 2s 389us/sample - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 22/30
# 5000/5000 [==============================] - 1s 285us/sample - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 23/30
# 5000/5000 [==============================] - 2s 398us/sample - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 24/30
# 5000/5000 [==============================] - 2s 357us/sample - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 25/30
# 5000/5000 [==============================] - 2s 311us/sample - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 26/30
# 5000/5000 [==============================] - 2s 343us/sample - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 27/30
# 5000/5000 [==============================] - 1s 287us/sample - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 28/30
# 5000/5000 [==============================] - 2s 342us/sample - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 29/30
# 5000/5000 [==============================] - 2s 391us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 30/30
# 5000/5000 [==============================] - 2s 378us/sample - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0022 - val_mean_squared_error: 0.0022

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# Osservo che la rete neurale fa estremamente fatica a lavorare in regioni in cui ha "visto" pochi dati. In particolare dunque è in difficoltà nelle code, dove non sono riuscito ad ottenere risultati significativamente migliori di questo. Questo effetto è ancora più evidente se si chiede alla rete neurale di predire risultati al di fuori della regione di cui "sa" qualcosa. Per esempio, spingendo la richiesta di predizione sul più ampio intervallo $[-1.5,1.5]$:

# %%
x_predicted = np.random.uniform(-1.5, 1.5, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_valid, y_target)
plt.grid(True)
plt.show()

# %% [markdown]
# # Funzione in due dimensioni #
#
# Tento ora di estendere il mio modello di rete neurale ad una funzione di due variabili reali (una superficie), precisamente:
# $$
# f(x,y) = \sin(x^2+y^2) \,\,\,\,;\,\,\, x \in [-3/2,3/2] \,\,\,\,\, ; \,\,\,\,\, y \in [-3/2,3/2]
# $$
# Comincio a generare i dataset di training e di validazione.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

np.random.seed(0)
num_training = 20000 # Numero di dati di training
num_valid = 1000     # Numero di dati di validazione
x_train = np.random.uniform(-1.5, 1.5, num_training)
y_train = np.random.uniform(-1.5, 1.5, num_training)
x_valid = np.random.uniform(-1.5, 1.5, num_valid)
y_valid = np.random.uniform(-1.5, 1.5, num_valid)
z_target = np.sin(x_valid**2 + y_valid**2)

sigma = 0.00 # Rumore per sporcare i dati.
z_train = np.random.normal(np.sin(x_train**2 + y_train**2), sigma)
z_valid = np.random.normal(np.sin(x_valid**2 + y_valid**2), sigma)

ax.scatter(x_valid, y_valid, z_valid, cmap=cm.coolwarm, marker=m)

plt.show()

# %% [markdown]
# In questo blocco preparo la rete neurale. Mi aspetto che debba essere un po' più complessa di quella usata per il fit di una funzione bidimensionale.

# %%
# In questo blocco preparo la rete neurale.
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects

model = tf.keras.Sequential()  # Modello sequenziale
model.add(Dense(1, input_shape=(1,)))  # In questo caso l'input è una coppia di valori.
model.add(Dense(20,activation = 'tanh'))   # Qui ho un altro layer di 10 neuroni con una RELU come
# funzione di attivazione.
model.add(Dense(30,activation = 'relu'))
model.add(Dense(20,activation='tanh'))
model.add(Dense(1,)) # Il layer di uscita ha un solo neurone, per ora senza funzione di attivazione.

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_108 (Dense)            (None, 1)                 2
# _________________________________________________________________
# dense_109 (Dense)            (None, 20)                40
# _________________________________________________________________
# dense_110 (Dense)            (None, 30)                630
# _________________________________________________________________
# dense_111 (Dense)            (None, 20)                620
# _________________________________________________________________
# dense_112 (Dense)            (None, 1)                 21
# =================================================================
# Total params: 1,313
# Trainable params: 1,313
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# In questo blocco eseguo il training della rete neurale.

# %%
bsize =32  # Dimensione del batch
lst = []
lst.append(x_train)
lst.append(y_train)
input_train = [x_train, y_train]  # Lista per i dati di training
input_valid = [x_valid, y_valid]
history=model.fit(x=lst, y=z_train, 
          batch_size=bsize, epochs=20, 
          validation_data=(input_valid, z_valid))
# Out:
# Train on 20000 samples, validate on 1000 samples
# Epoch 1/20
# 20000/20000 [==============================] - 12s 624us/sample - loss: 0.1514 - mean_squared_error: 0.1514 - val_loss: 0.1368 - val_mean_squared_error: 0.1368
# Epoch 2/20
# 20000/20000 [==============================] - 11s 552us/sample - loss: 0.1473 - mean_squared_error: 0.1473 - val_loss: 0.1366 - val_mean_squared_error: 0.1366
# Epoch 3/20
# 20000/20000 [==============================] - 11s 544us/sample - loss: 0.1453 - mean_squared_error: 0.1453 - val_loss: 0.1333 - val_mean_squared_error: 0.1333
# Epoch 4/20
# 20000/20000 [==============================] - 11s 561us/sample - loss: 0.1435 - mean_squared_error: 0.1435 - val_loss: 0.1316 - val_mean_squared_error: 0.1316
# Epoch 5/20
# 20000/20000 [==============================] - 11s 550us/sample - loss: 0.1415 - mean_squared_error: 0.1415 - val_loss: 0.1311 - val_mean_squared_error: 0.1311
# Epoch 6/20
# 20000/20000 [==============================] - 11s 544us/sample - loss: 0.1399 - mean_squared_error: 0.1399 - val_loss: 0.1274 - val_mean_squared_error: 0.1274
# Epoch 7/20
# 20000/20000 [==============================] - 12s 603us/sample - loss: 0.1379 - mean_squared_error: 0.1379 - val_loss: 0.1257 - val_mean_squared_error: 0.1257
# Epoch 8/20
# 20000/20000 [==============================] - 11s 568us/sample - loss: 0.1366 - mean_squared_error: 0.1366 - val_loss: 0.1279 - val_mean_squared_error: 0.1279
# Epoch 9/20
# 20000/20000 [==============================] - 11s 573us/sample - loss: 0.1351 - mean_squared_error: 0.1351 - val_loss: 0.1232 - val_mean_squared_error: 0.1232
# Epoch 10/20
# 20000/20000 [==============================] - 11s 574us/sample - loss: 0.1347 - mean_squared_error: 0.1347 - val_loss: 0.1262 - val_mean_squared_error: 0.1262
# Epoch 11/20
# 20000/20000 [==============================] - 13s 630us/sample - loss: 0.1341 - mean_squared_error: 0.1341 - val_loss: 0.1227 - val_mean_squared_error: 0.1227
# Epoch 12/20
# 20000/20000 [==============================] - 12s 625us/sample - loss: 0.1337 - mean_squared_error: 0.1337 - val_loss: 0.1226 - val_mean_squared_error: 0.1226
# Epoch 13/20
# 20000/20000 [==============================] - 11s 567us/sample - loss: 0.1335 - mean_squared_error: 0.1335 - val_loss: 0.1229 - val_mean_squared_error: 0.1229
# Epoch 14/20
# 20000/20000 [==============================] - 13s 655us/sample - loss: 0.1329 - mean_squared_error: 0.1329 - val_loss: 0.1236 - val_mean_squared_error: 0.1236
# Epoch 15/20
# 20000/20000 [==============================] - 12s 594us/sample - loss: 0.1332 - mean_squared_error: 0.1332 - val_loss: 0.1217 - val_mean_squared_error: 0.1217
# Epoch 16/20
# 20000/20000 [==============================] - 11s 555us/sample - loss: 0.1330 - mean_squared_error: 0.1330 - val_loss: 0.1235 - val_mean_squared_error: 0.1235
# Epoch 17/20
# 20000/20000 [==============================] - 13s 626us/sample - loss: 0.1332 - mean_squared_error: 0.1332 - val_loss: 0.1220 - val_mean_squared_error: 0.1220
# Epoch 18/20
# 20000/20000 [==============================] - 12s 622us/sample - loss: 0.1333 - mean_squared_error: 0.1333 - val_loss: 0.1220 - val_mean_squared_error: 0.1220
# Epoch 19/20
# 20000/20000 [==============================] - 13s 649us/sample - loss: 0.1330 - mean_squared_error: 0.1330 - val_loss: 0.1230 - val_mean_squared_error: 0.1230
# Epoch 20/20
# 20000/20000 [==============================] - 12s 576us/sample - loss: 0.1330 - mean_squared_error: 0.1330 - val_loss: 0.1246 - val_mean_squared_error: 0.1246

# %% [markdown]
# Valuto ora la capacità predittiva della rete neurale.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 

x_predicted = np.random.uniform(-1.5, 1.5, 1000)
y_predicted = np.random.uniform(-1.5, 1.5, 1000)
lst = [x_predicted, y_predicted]
z_predicted = model.predict(lst)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(x_predicted, y_predicted, z_predicted, c=c, marker=m)

plt.show()
